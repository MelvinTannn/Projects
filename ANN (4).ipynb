# %%
#!pip install --upgrade tensorflow

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
dataset = pd.read_csv('winequalityN.csv')
labels = dataset['type'].values
dataset
# Out:
#        type  fixed acidity  volatile acidity  ...  sulphates  alcohol  quality
# 0     white            7.0             0.270  ...       0.45      8.8        6
# 1     white            6.3             0.300  ...       0.49      9.5        6
# 2     white            8.1             0.280  ...       0.44     10.1        6
# 3     white            7.2             0.230  ...       0.40      9.9        6
# 4     white            7.2             0.230  ...       0.40      9.9        6
# ...     ...            ...               ...  ...        ...      ...      ...
# 6492    red            6.2             0.600  ...       0.58     10.5        5
# 6493    red            5.9             0.550  ...        NaN     11.2        6
# 6494    red            6.3             0.510  ...       0.75     11.0        6
# 6495    red            5.9             0.645  ...       0.71     10.2        5
# 6496    red            6.0             0.310  ...       0.66     11.0        6
#
# ...

# %%
dataset['type'] = LabelEncoder().fit_transform(dataset['type'])
dataset = dataset.fillna(dataset.mean())
dataset
# Out:
#       type  fixed acidity  volatile acidity  ...  sulphates  alcohol  quality
# 0        1            7.0             0.270  ...   0.450000      8.8        6
# 1        1            6.3             0.300  ...   0.490000      9.5        6
# 2        1            8.1             0.280  ...   0.440000     10.1        6
# 3        1            7.2             0.230  ...   0.400000      9.9        6
# 4        1            7.2             0.230  ...   0.400000      9.9        6
# ...    ...            ...               ...  ...        ...      ...      ...
# 6492     0            6.2             0.600  ...   0.580000     10.5        5
# 6493     0            5.9             0.550  ...   0.531215     11.2        6
# 6494     0            6.3             0.510  ...   0.750000     11.0        6
# 6495     0            5.9             0.645  ...   0.710000     10.2        5
# 6496     0            6.0             0.310  ...   0.660000     11.0        6
#
# [6497 rows x 13 columns]

# %% [markdown]
# Pada bagian ini dapat dilihat bahwa saya menggunakan label encoder untuk dapat menencode data pada kolom type yang sebelumnya berbentuk atau berformat string untuk dapat menjadi integer sehingga dapat dibaca oleh program.

# %%
dataset = StandardScaler().fit_transform(dataset)

# %% [markdown]
# Pada bagian ini dataset juga di scaler menggunakan standardscaler agar hasil yang didapat juga menjadi optimal dan tepat.

# %%
from sklearn import decomposition
pca = decomposition.PCA()

pca.n_components = 2
pca_data = pca.fit_transform(dataset)

print('shape of pca_reduced.shape = ', pca_data.shape)
# Out:
# shape of pca_reduced.shape =  (6497, 2)

# %% [markdown]
# Pada bagian ini PCA dilakukan sehingga bentuk topologi dimensinya dapat berkurang menjadi 2 dimensi

# %%
import seaborn as sn
pca_data = np.vstack((pca_data.T, labels)).T

pca_df = pd.DataFrame(data=pca_data, columns=('1st_principal', '2nd_principal', 'label'))
sn.FacetGrid(pca_df, hue='label', size=6).map(plt.scatter, '1st_principal', '2nd_principal').add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
